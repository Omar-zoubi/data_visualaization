# %%
import pandas as pd 
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('./fundamentals.csv')
df.tail(5)
# Out:
#       Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 1776        1776          ZION    2015-12-31      0.000000e+00
# 1777        1777           ZTS    2013-12-31      1.381000e+09
# 1778        1778           ZTS    2014-12-31      1.071000e+09
# 1779        1779           ZTS    2015-12-31      1.313000e+09
# 1780        1780           ZTS    2016-12-31      1.076000e+09
#
#       Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 1776                  0.0                  -2530000.0            4.0
# 1777          -99000000.0                   9000000.0           54.0
# 1778           69000000.0                  -7000000.0           44.0
# 1779          -58000000.0                 -81000000.0           32.0
# 1780           15000000.0                   2000000.0           55.0
#
#       Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 1776          -157361000.0     0.000000e+00         NaN  ...
# ...

# %% [markdown]
# # Calculate the avag of Capital Expenditures:

# %%
avg_capital_exp = df.groupby("Period Ending",as_index = False).mean()
avg_capital_exp.head(5)
period = df[["Period Ending","Capital Expenditures"]].groupby("Period Ending",as_index = False).mean()
period.head(5)
# Out:
#   Period Ending  Capital Expenditures
# 0    2003-06-30              -74000.0
# 1    2004-06-30              -50000.0
# 2    2006-02-28            -1361000.0
# 3    2007-02-28             -896000.0
# 4    2012-03-03          -766000000.0

# %% [markdown]
# # Calculating avg Total Revenue per a spacific period:

# %%
avg_total_rev = df.groupby("Period Ending",as_index = False).mean()
avg_total_rev.head(5)
period = df[["Period Ending","Total Revenue"]].groupby("Period Ending",as_index = False).mean()
period.head(5)
# Out:
#   Period Ending  Total Revenue
# 0    2003-06-30   1.577000e+06
# 1    2004-06-30   1.514000e+06
# 2    2006-02-28   7.956200e+07
# 3    2007-02-28   9.964200e+07
# 4    2012-03-03   4.545700e+10

# %%
sns.set()

# %%
sns.barplot(x='Period Ending',y='Total Revenue',data=avg_total_rev)
# Out:
# <AxesSubplot:xlabel='Period Ending', ylabel='Total Revenue'>
